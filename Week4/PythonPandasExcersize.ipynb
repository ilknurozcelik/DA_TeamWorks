# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1: From the given dataset print the first and last five rows

# %%
df = pd.read_csv("Automobile_data.csv")

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# ## Exercise 2: Clean the dataset and update the CSV file
#
# Replace all column values which contain ?, n.a, or NaN.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df.rename({'body-style': 'body_style' ,
                   'wheel-base':'wheel_base',
                   'engine-type':'engine_type',
                   "num-of-cylinders":"num_of_cylinders",
                   "average-mileage":"average_mileage"},
                  inplace=True, axis=1)
df.head()
# Out:
#    index      company   body_style  wheel_base  length engine_type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num_of_cylinders  horsepower  average_mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
for i in df.columns :
    print(i, "--"*20)  
    print(df[i].value_counts())
    print("#"*20)
# Out:
# index ----------------------------------------
# 0     1
# 43    1
# 45    1
# 46    1
# 47    1
#      ..
# 34    1
# 35    1
# 36    1
# 37    1
# 88    1
# Name: index, Length: 61, dtype: int64
# ####################
# company ----------------------------------------
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64
# ####################
# body_style ----------------------------------------
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: body_style, dtype: int64
# ####################
# wheel_base ----------------------------------------
# 94.5     9
# 95.7     6
# 97.3     4
# 93.7     4
# 101.2    3
# ...

# %%
(df.isin(["?"])).sum()
# Out:
# index               0
# company             0
# body_style          0
# wheel_base          0
# length              0
# engine_type         0
# num_of_cylinders    0
# horsepower          0
# average_mileage     0
# price               0
# dtype: int64

# %%
(df.isin(["n.a"])).sum()
# Out:
# index               0
# company             0
# body_style          0
# wheel_base          0
# length              0
# engine_type         0
# num_of_cylinders    0
# horsepower          0
# average_mileage     0
# price               0
# dtype: int64

# %%
(df.isin([np.nan])).sum()
# Out:
# index               0
# company             0
# body_style          0
# wheel_base          0
# length              0
# engine_type         0
# num_of_cylinders    0
# horsepower          0
# average_mileage     0
# price               3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body_style          0
# wheel_base          0
# length              0
# engine_type         0
# num_of_cylinders    0
# horsepower          0
# average_mileage     0
# price               3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             58 non-null     int64
#  1   company           58 non-null     object
#  2   body_style        58 non-null     object
#  3   wheel_base        58 non-null     float64
#  4   length            58 non-null     float64
#  5   engine_type       58 non-null     object
#  6   num_of_cylinders  58 non-null     object
#  7   horsepower        58 non-null     int64
#  8   average_mileage   58 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.0+ KB

# %%
df.to_csv("Automobile_data_cleaned.csv", index=False)

# %%
df_clenaed=pd.read_csv("Automobile_data_cleaned.csv")
df_clenaed.head()
# Out:
#    index      company   body_style  wheel_base  length engine_type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num_of_cylinders  horsepower  average_mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %% [markdown]
# ## Exercise 3: Find the most expensive car company name
# Print most expensive car’s company name and price.

# %%
df_clenaed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             58 non-null     int64
#  1   company           58 non-null     object
#  2   body_style        58 non-null     object
#  3   wheel_base        58 non-null     float64
#  4   length            58 non-null     float64
#  5   engine_type       58 non-null     object
#  6   num_of_cylinders  58 non-null     object
#  7   horsepower        58 non-null     int64
#  8   average_mileage   58 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.7+ KB

# %%
df_clenaed.price.max()
# Out:
# 45400.0

# %%
df_clenaed.loc[(df.price == df.price.max(), ["company", "price"])]
# Out:
#           company    price
# 33  mercedes-benz  45400.0

# %% [markdown]
# ## Exercise 4: Print All Toyota Cars details

# %%
df_clenaed[df_clenaed.company == "toyota"]
# Out:
#     index company body_style  wheel_base  length engine_type num_of_cylinders  \
# 45     66  toyota  hatchback        95.7   158.7         ohc             four
# 46     67  toyota  hatchback        95.7   158.7         ohc             four
# 47     68  toyota  hatchback        95.7   158.7         ohc             four
# 48     69  toyota      wagon        95.7   169.7         ohc             four
# 49     70  toyota      wagon        95.7   169.7         ohc             four
# 50     71  toyota      wagon        95.7   169.7         ohc             four
# 51     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average_mileage    price
# 45          62               35   5348.0
# 46          62               31   6338.0
# 47          62               31   6488.0
# 48          62               31   6918.0
# 49          62               27   7898.0
# 50          62               27   8778.0
# 51         156               19  15750.0

# %% [markdown]
# ## Exercise 5: Count total cars per company

# %%
df_clenaed.company.value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# jaguar           3
# dodge            2
# porsche          2
# volvo            2
# isuzu            1
# Name: company, dtype: int64

# %% [markdown]
# ## Exercise 6: Find each company’s Higesht price car

# %%
df_clenaed.groupby("company")[["company", "price"]].max()
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %% [markdown]
# ## Exercise 7: Find the average mileage of each car making company

# %%
df_clenaed.groupby("company")[["average_mileage"]].mean()
# Out:
#                average_mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                24.000000
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %% [markdown]
# ## Exercise 8: Sort all cars by Price column

# %%
df_clenaed.sort_values(by="price",ascending=False).head()
# Out:
#     index        company   body_style  wheel_base  length engine_type  \
# 33     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 32     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 44     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num_of_cylinders  horsepower  average_mileage    price
# 33            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 32            eight         184               14  40960.0
# 44              six         207               17  37028.0
# 12              six         182               15  36880.0

# %% [markdown]
# ## Exercise 9: Concatenate two data frames using the following conditions

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
df_German = pd.DataFrame(GermanCars)
df_German
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
df_Japan = pd.DataFrame(japaneseCars)
df_Japan
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
pd.concat((df_German, df_Japan), keys=["Germany","Japan"])
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# ## Exercise 10: Merge two data frames using the following condition
# Create two data frames using the following two Dicts, Merge two data frames,
#
# and append the second data frame as a new column to the first data frame.

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
df_price=pd.DataFrame(Car_Price)
df_price
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
df_hpw=pd.DataFrame(car_Horsepower)
df_hpw
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
pd.merge(df_price,df_hpw, on="Company")
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
